# %%
import matplotlib.pyplot as plt
import numpy as np

import keras

# %%
N = 100
D = 2
K = 3
X = np.zeros((N * K, D))
y = np.zeros(N * K, dtype='uint8')

for j in range(K):
    ix = range(N * j,N * (j + 1))
    r = np.linspace(0.0, 1, N)
    t = np.linspace(j * 4, (j + 1) * 4,N) + np.random.randn(N) * 0.2 # theta
    X[ix] = np.c_[r * np.sin(t), r * np.cos(t)]
    y[ix] = j

# %%
plt.figure(figsize=(10, 8))
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.rainbow)
plt.title('Спираль', fontsize=15)
plt.xlabel('$x$', fontsize=14)
plt.ylabel('$y$', fontsize=14)
plt.show()

# %%
print(X.data.shape, y.data.shape)
# Out:
# (300, 2) (300,)

# %%
y = keras.utils.to_categorical(y, 3)

# %%
from keras import optimizers
import tensorflow as tf
two_layer_net=keras.models.Sequential()
two_layer_net.add(keras.layers.Dense(100, input_shape=(X.shape[1],), activation='relu'))
two_layer_net.add(keras.layers.Dense(3, activation='softmax'))
print(two_layer_net.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               300
#
#  dense_1 (Dense)             (None, 3)                 303
#
# =================================================================
# Total params: 603 (2.36 KB)
# Trainable params: 603 (2.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
import keras
import tensorflow as tf
from keras.utils import plot_model
plot_model(two_layer_net, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
sgd = tf.keras.optimizers.legacy.SGD(decay=1e-6, momentum=0.9, nesterov=True, learning_rate=0.01)
two_layer_net.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
history=two_layer_net.fit(X, y, epochs=150, batch_size=64, verbose=0, validation_split=0.2)

# %%
plt.plot(history.history['accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
#plt.legend(['train','test'])
plt.show()

# %%
many_layer_net=keras.models.Sequential()
two_layer_net.add(keras.layers.Dense(100, input_shape=(X.shape[1],), activation='relu'))
two_layer_net.add(keras.layers.Dense(100, activation='relu'))
two_layer_net.add(keras.layers.Dense(100, activation='relu'))
two_layer_net.add(keras.layers.Dense(3, activation='softmax'))
sgd = tf.keras.optimizers.legacy.SGD(decay=1e-6, momentum=0.9, nesterov=True, learning_rate=0.001)
two_layer_net.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
history=two_layer_net.fit(X, y, epochs=150, batch_size=64, verbose=0, validation_split=0.2)

# %%
plt.plot(history.history['accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %%
many_layer_net=keras.models.Sequential()
two_layer_net.add(keras.layers.Dense(100, input_shape=(X.shape[1],), activation='relu'))
two_layer_net.add(keras.layers.Dense(100, activation='relu'))
two_layer_net.add(keras.layers.Dense(100, activation='relu'))
two_layer_net.add(keras.layers.Dense(3, activation='softmax'))
sgd = tf.keras.optimizers.legacy.SGD(decay=1e-6, momentum=0.9, nesterov=True, learning_rate=0.5)
two_layer_net.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
history=two_layer_net.fit(X, y, epochs=150, batch_size=64, verbose=0, validation_split=0.2)

# %%
plt.plot(history.history['accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %%
many_layer_net=keras.models.Sequential()
two_layer_net.add(keras.layers.Dense(100, input_shape=(X.shape[1],), activation='relu'))
two_layer_net.add(keras.layers.Dense(100, activation='relu'))
two_layer_net.add(keras.layers.Dense(100, activation='relu'))
two_layer_net.add(keras.layers.Dense(3, activation='softmax'))
sgd = tf.keras.optimizers.legacy.SGD(decay=1e-6, momentum=0.9, nesterov=True, learning_rate=0.001)
two_layer_net.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
history=two_layer_net.fit(X, y, epochs=200, batch_size=64, verbose=0, validation_split=0.2)

# %%
plt.plot(history.history['accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %%
many_layer_net=keras.models.Sequential()
two_layer_net.add(keras.layers.Dense(100, input_shape=(X.shape[1],), activation='relu'))
two_layer_net.add(keras.layers.Dense(100, activation='relu'))
two_layer_net.add(keras.layers.Dense(100, activation='relu'))
two_layer_net.add(keras.layers.Dense(3, activation='softmax'))
Adam = tf.keras.optimizers.legacy.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, amsgrad=False)
two_layer_net.compile(loss='categorical_crossentropy', optimizer=Adam, metrics=['accuracy'])
history=two_layer_net.fit(X, y, epochs=150, batch_size=64, verbose=0, validation_split=0.2)

# %%
plt.plot(history.history['accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %%
many_layer_net=keras.models.Sequential()
two_layer_net.add(keras.layers.Dense(100, input_shape=(X.shape[1],), activation='relu'))
two_layer_net.add(keras.layers.Dense(100, activation='relu'))
two_layer_net.add(keras.layers.Dense(100, activation='relu'))
two_layer_net.add(keras.layers.Dense(3, activation='softmax'))
Rmsp = tf.keras.optimizers.legacy.RMSprop(learning_rate=0.001, rho=0.9, epsilon=1e-07)
two_layer_net.compile(loss='categorical_crossentropy', optimizer=Rmsp, metrics=['accuracy'])
history=two_layer_net.fit(X, y, epochs=150, batch_size=64, verbose=0, validation_split=0.2)

# %%
plt.plot(history.history['accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %%
many_layer_net=keras.models.Sequential()
two_layer_net.add(keras.layers.Dense(150, input_shape=(X.shape[1],), activation='relu'))
two_layer_net.add(keras.layers.Dense(150, activation='relu'))
two_layer_net.add(keras.layers.Dense(150, activation='relu'))
two_layer_net.add(keras.layers.Dense(3, activation='softmax'))
sgd = tf.keras.optimizers.legacy.SGD(decay=1e-6, momentum=0.9, nesterov=True, learning_rate=0.001)
two_layer_net.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
history=two_layer_net.fit(X, y, epochs=150, batch_size=64, verbose=0, validation_split=0.2)

# %%
plt.plot(history.history['accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %%
many_layer_net=keras.models.Sequential()
two_layer_net.add(keras.layers.Dense(100, input_shape=(X.shape[1],), activation='relu'))
two_layer_net.add(keras.layers.Dense(100, activation='relu'))
two_layer_net.add(keras.layers.Dense(100, activation='relu'))
two_layer_net.add(keras.layers.Dense(100, activation='relu'))
two_layer_net.add(keras.layers.Dense(3, activation='softmax'))
sgd = tf.keras.optimizers.legacy.SGD(decay=1e-6, momentum=0.9, nesterov=True, learning_rate=0.001)
two_layer_net.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
history=two_layer_net.fit(X, y, epochs=150, batch_size=64, verbose=0, validation_split=0.2)

# %%
plt.plot(history.history['accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %%
many_layer_net=keras.models.Sequential()
two_layer_net.add(keras.layers.Dense(100, input_shape=(X.shape[1],), activation='relu'))
two_layer_net.add(keras.layers.Dropout(0.5))
two_layer_net.add(keras.layers.Dense(100, activation='relu'))
two_layer_net.add(keras.layers.Dropout(0.5))
two_layer_net.add(keras.layers.Dense(100, activation='relu'))
two_layer_net.add(keras.layers.Dropout(0.5))
two_layer_net.add(keras.layers.Dense(3, activation='softmax'))
sgd = tf.keras.optimizers.legacy.SGD(decay=1e-6, momentum=0.9, nesterov=True, learning_rate=0.001)
two_layer_net.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
history=two_layer_net.fit(X, y, epochs=150, batch_size=64, verbose=0, validation_split=0.2)

# %%
plt.plot(history.history['accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %%
many_layer_net=keras.models.Sequential()
two_layer_net.add(keras.layers.Dense(100, input_shape=(X.shape[1],), activation='relu'))
many_layer_net.add(keras.layers.BatchNormalization())
two_layer_net.add(keras.layers.Dense(100, activation='relu'))
two_layer_net.add(keras.layers.Dense(100, activation='relu'))
two_layer_net.add(keras.layers.Dense(3, activation='softmax'))
sgd = tf.keras.optimizers.legacy.SGD(decay=1e-6, momentum=0.9, nesterov=True, learning_rate=0.001)
two_layer_net.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
history=two_layer_net.fit(X, y, epochs=150, batch_size=64, verbose=0, validation_split=0.2)

# %%
plt.plot(history.history['accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %% [markdown]
# # Задание **2**

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
import keras
from keras.datasets import mnist
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.models import Sequential
from tensorflow.python.keras.utils import np_utils
from tensorflow.python.keras.optimizers import adam_v2

import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

number_of_classes = 10

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

plt.figure()
plt.imshow(X_train[0])
plt.colorbar()
plt.grid(False)

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i], cmap=plt.cm.binary)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1]*X_train.shape[2]).astype('float32')
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1]*X_test.shape[2]).astype('float32')

#для преобразования двумерных данных в одномерные в нейронной сети можно использовать слой Flatten(input_shape=(28,28))

X_train/=255
X_test/=255

y_train = np_utils.to_categorical(y_train, number_of_classes)
y_test = np_utils.to_categorical(y_test, number_of_classes)

# %%
X_train.shape
# Out:
# (60000, 784)

# %%
model = keras.models.Sequential()
model.add(keras.layers.Dense(512, input_dim=(X_train.shape[1]), activation='relu'))
model.add(keras.layers.Dense(number_of_classes, activation='softmax'))
print(model.summary())
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_60 (Dense)            (None, 512)               401920
#
#  dense_61 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 407050 (1.55 MB)
# Trainable params: 407050 (1.55 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history=model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5, batch_size=200)
# Out:
# Epoch 1/5
# 300/300 [==============================] - 6s 19ms/step - loss: 0.2998 - accuracy: 0.9171 - val_loss: 0.1497 - val_accuracy: 0.9565
# Epoch 2/5
# 300/300 [==============================] - 5s 15ms/step - loss: 0.1255 - accuracy: 0.9642 - val_loss: 0.1084 - val_accuracy: 0.9682
# Epoch 3/5
# 300/300 [==============================] - 5s 15ms/step - loss: 0.0836 - accuracy: 0.9754 - val_loss: 0.0872 - val_accuracy: 0.9723
# Epoch 4/5
# 300/300 [==============================] - 5s 16ms/step - loss: 0.0604 - accuracy: 0.9825 - val_loss: 0.0740 - val_accuracy: 0.9763
# Epoch 5/5
# 300/300 [==============================] - 4s 13ms/step - loss: 0.0455 - accuracy: 0.9869 - val_loss: 0.0736 - val_accuracy: 0.9778

# %%
#оценка точности
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
print('Test loss:', test_loss)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0736 - accuracy: 0.9778
# Test accuracy: 0.9778000116348267
# Test loss: 0.07357370853424072

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax1.plot(history.history['accuracy'])
ax1.plot(history.history['val_accuracy'])
ax1.set(title='model accuracy')
ax1.set(ylabel='accuracy')
ax1.set(xlabel='epoch')
ax1.legend(['train', 'test'], loc='upper left')
ax2 = fig.add_subplot(1,2,2)
ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set(title='model loss')
ax2.set(ylabel='loss')
ax2.set(xlabel='epoch')
ax2.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model = keras.models.Sequential()
model.add(keras.layers.Dense(512, input_dim=(X_train.shape[1]), activation='relu'))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(number_of_classes, activation='softmax'))
print(model.summary())
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_62 (Dense)            (None, 512)               401920
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_63 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 407050 (1.55 MB)
# Trainable params: 407050 (1.55 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history=model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5, batch_size=200)
# Out:
# Epoch 1/5
# 300/300 [==============================] - 6s 17ms/step - loss: 0.3705 - accuracy: 0.8926 - val_loss: 0.1726 - val_accuracy: 0.9489
# Epoch 2/5
# 300/300 [==============================] - 6s 19ms/step - loss: 0.1731 - accuracy: 0.9491 - val_loss: 0.1156 - val_accuracy: 0.9664
# Epoch 3/5
# 300/300 [==============================] - 4s 14ms/step - loss: 0.1294 - accuracy: 0.9623 - val_loss: 0.0943 - val_accuracy: 0.9716
# Epoch 4/5
# 300/300 [==============================] - 5s 16ms/step - loss: 0.1056 - accuracy: 0.9691 - val_loss: 0.0785 - val_accuracy: 0.9758
# Epoch 5/5
# 300/300 [==============================] - 5s 17ms/step - loss: 0.0901 - accuracy: 0.9733 - val_loss: 0.0733 - val_accuracy: 0.9781

# %%
#оценка точности
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
print('Test loss:', test_loss)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0733 - accuracy: 0.9781
# Test accuracy: 0.9781000018119812
# Test loss: 0.07330325245857239

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax1.plot(history.history['accuracy'])
ax1.plot(history.history['val_accuracy'])
ax1.set(title='model accuracy')
ax1.set(ylabel='accuracy')
ax1.set(xlabel='epoch')
ax1.legend(['train', 'test'], loc='upper left')
ax2 = fig.add_subplot(1,2,2)
ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set(title='model loss')
ax2.set(ylabel='loss')
ax2.set(xlabel='epoch')
ax2.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model = keras.models.Sequential()
model.add(keras.layers.Dense(512, input_dim=(X_train.shape[1]), activation='relu'))
model.add(keras.layers.Dense(512, input_dim=(X_train.shape[1]), activation='relu'))
model.add(keras.layers.Dense(number_of_classes, activation='softmax'))
print(model.summary())
# Out:
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_64 (Dense)            (None, 512)               401920
#
#  dense_65 (Dense)            (None, 512)               262656
#
#  dense_66 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 669706 (2.55 MB)
# Trainable params: 669706 (2.55 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history=model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5, batch_size=200)
# Out:
# Epoch 1/5
# 300/300 [==============================] - 10s 30ms/step - loss: 0.2445 - accuracy: 0.9297 - val_loss: 0.1083 - val_accuracy: 0.9655
# Epoch 2/5
# 300/300 [==============================] - 7s 23ms/step - loss: 0.0850 - accuracy: 0.9743 - val_loss: 0.0802 - val_accuracy: 0.9737
# Epoch 3/5
# 300/300 [==============================] - 7s 25ms/step - loss: 0.0540 - accuracy: 0.9830 - val_loss: 0.0679 - val_accuracy: 0.9782
# Epoch 4/5
# 300/300 [==============================] - 7s 23ms/step - loss: 0.0356 - accuracy: 0.9890 - val_loss: 0.0686 - val_accuracy: 0.9793
# Epoch 5/5
# 300/300 [==============================] - 7s 24ms/step - loss: 0.0264 - accuracy: 0.9919 - val_loss: 0.0720 - val_accuracy: 0.9780

# %%
#оценка точности
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
print('Test loss:', test_loss)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0720 - accuracy: 0.9780
# Test accuracy: 0.9779999852180481
# Test loss: 0.07195991277694702

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax1.plot(history.history['accuracy'])
ax1.plot(history.history['val_accuracy'])
ax1.set(title='model accuracy')
ax1.set(ylabel='accuracy')
ax1.set(xlabel='epoch')
ax1.legend(['train', 'test'], loc='upper left')
ax2 = fig.add_subplot(1,2,2)
ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set(title='model loss')
ax2.set(ylabel='loss')
ax2.set(xlabel='epoch')
ax2.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Задание 3

# %%
from keras.regularizers import l2
l2_lambda = 0.0001
model_reg = keras.models.Sequential()
model_reg.add(keras.layers.Dense(512, input_dim=(X_train.shape[1]), activation='relu',kernel_initializer='he_uniform', bias_regularizer=l2(l2_lambda)))
model_reg.add(keras.layers.Dense(number_of_classes, activation='softmax', kernel_initializer='glorot_uniform'))

# %%
model_reg.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history=model_reg.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5, batch_size=200)
# Out:
# Epoch 1/5
# 300/300 [==============================] - 6s 16ms/step - loss: 0.3060 - accuracy: 0.9142 - val_loss: 0.1599 - val_accuracy: 0.9540
# Epoch 2/5
# 300/300 [==============================] - 4s 14ms/step - loss: 0.1254 - accuracy: 0.9643 - val_loss: 0.1121 - val_accuracy: 0.9672
# Epoch 3/5
# 300/300 [==============================] - 5s 18ms/step - loss: 0.0845 - accuracy: 0.9759 - val_loss: 0.0856 - val_accuracy: 0.9728
# Epoch 4/5
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0593 - accuracy: 0.9829 - val_loss: 0.0780 - val_accuracy: 0.9749
# Epoch 5/5
# 300/300 [==============================] - 4s 13ms/step - loss: 0.0453 - accuracy: 0.9871 - val_loss: 0.0695 - val_accuracy: 0.9782

# %%
from keras.regularizers import l2
l2_lambda = 0.5
model_reg = keras.models.Sequential()
model_reg.add(keras.layers.Dense(512, input_dim=(X_train.shape[1]), activation='relu',kernel_initializer='he_uniform', bias_regularizer=l2(l2_lambda)))
model_reg.add(keras.layers.Dense(number_of_classes, activation='softmax', kernel_initializer='glorot_uniform'))

# %%
model_reg.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history=model_reg.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5, batch_size=200)
# Out:
# Epoch 1/5
# 300/300 [==============================] - 6s 17ms/step - loss: 0.3036 - accuracy: 0.9156 - val_loss: 0.1576 - val_accuracy: 0.9534
# Epoch 2/5
# 300/300 [==============================] - 4s 14ms/step - loss: 0.1240 - accuracy: 0.9646 - val_loss: 0.1011 - val_accuracy: 0.9707
# Epoch 3/5
# 300/300 [==============================] - 4s 13ms/step - loss: 0.0813 - accuracy: 0.9772 - val_loss: 0.0854 - val_accuracy: 0.9748
# Epoch 4/5
# 300/300 [==============================] - 5s 16ms/step - loss: 0.0596 - accuracy: 0.9831 - val_loss: 0.0860 - val_accuracy: 0.9736
# Epoch 5/5
# 300/300 [==============================] - 4s 13ms/step - loss: 0.0459 - accuracy: 0.9863 - val_loss: 0.0737 - val_accuracy: 0.9745

# %%
from keras.regularizers import l2
l2_lambda = 0.01
model_reg = keras.models.Sequential()
model_reg.add(keras.layers.Dense(512, input_dim=(X_train.shape[1]), activation='relu',kernel_initializer='he_uniform', bias_regularizer=l2(l2_lambda)))
model_reg.add(keras.layers.Dense(number_of_classes, activation='softmax', kernel_initializer='glorot_uniform'))

# %%
model_reg.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history=model_reg.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5, batch_size=200)
# Out:
# Epoch 1/5
# 300/300 [==============================] - 6s 17ms/step - loss: 0.3037 - accuracy: 0.9139 - val_loss: 0.1532 - val_accuracy: 0.9549
# Epoch 2/5
# 300/300 [==============================] - 4s 14ms/step - loss: 0.1251 - accuracy: 0.9645 - val_loss: 0.0993 - val_accuracy: 0.9713
# Epoch 3/5
# 300/300 [==============================] - 4s 13ms/step - loss: 0.0828 - accuracy: 0.9769 - val_loss: 0.0829 - val_accuracy: 0.9749
# Epoch 4/5
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0598 - accuracy: 0.9833 - val_loss: 0.0748 - val_accuracy: 0.9760
# Epoch 5/5
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0446 - accuracy: 0.9874 - val_loss: 0.0666 - val_accuracy: 0.9797

# %%
from keras.regularizers import l2
l2_lambda = 1
model_reg = keras.models.Sequential()
model_reg.add(keras.layers.Dense(512, input_dim=(X_train.shape[1]), activation='relu',kernel_initializer='he_uniform', bias_regularizer=l2(l2_lambda)))
model_reg.add(keras.layers.Dense(number_of_classes, activation='softmax', kernel_initializer='glorot_uniform'))

# %%
model_reg.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history=model_reg.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5, batch_size=200)
# Out:
# Epoch 1/5
# 300/300 [==============================] - 5s 14ms/step - loss: 0.2987 - accuracy: 0.9162 - val_loss: 0.1612 - val_accuracy: 0.9538
# Epoch 2/5
# 300/300 [==============================] - 5s 16ms/step - loss: 0.1232 - accuracy: 0.9650 - val_loss: 0.1076 - val_accuracy: 0.9672
# Epoch 3/5
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0810 - accuracy: 0.9770 - val_loss: 0.0918 - val_accuracy: 0.9731
# Epoch 4/5
# 300/300 [==============================] - 4s 13ms/step - loss: 0.0590 - accuracy: 0.9828 - val_loss: 0.0728 - val_accuracy: 0.9782
# Epoch 5/5
# 300/300 [==============================] - 5s 16ms/step - loss: 0.0435 - accuracy: 0.9880 - val_loss: 0.0648 - val_accuracy: 0.9789

# %%
#выполняем преобразование картинки с цифрой
from PIL import Image
#преобразование входного изображения в формат набора MNIS
image=Image.open("cifra-2.png").resize((28,28))
img = np.invert(image.convert('L')).ravel()
im2arr = img.reshape(1, 28* 28).astype('float32')/255
#plt.imshow(image, cmap=plt.cm.binary)
#использование обученной модели
y_pred = model.predict(im2arr)
print(y_pred[0])
plt.bar(range(10), y_pred[0])
plt.show()
print(np.argmax(y_pred))
# Out:
# 1/1 [==============================] - 0s 71ms/step
# [8.6541258e-06 3.6340219e-04 7.4899659e-02 8.1756926e-01 1.3804008e-20
#  1.0583063e-01 5.5187996e-08 8.9393598e-06 1.3193658e-03 4.1631468e-12]
# 3

# %%
model.save('model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# Задание 4

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Загрузка датасета вина
wine = datasets.load_wine()

# Разделение данных на признаки и целевую переменную
X = wine.data
y = wine.target

# Разделение данных на обучающую и тестовую выборки
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=0)
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Входной слой: количество нейронов соответствует количеству признаков в датасете
num_features = X_train.shape[1]
# Выходной слой: количество нейронов соответствует количеству классов в датасете
num_classes = len(np.unique(y_train))
# Создаем модель
model_wine = keras.Sequential([
    keras.layers.Dense(64, activation='relu', input_shape=(num_features,)),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(num_classes, activation='softmax')
])

# %%
from tensorflow.keras.utils import plot_model
plot_model(model_wine, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model_wine.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model_wine.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 2s 102ms/step - loss: 1.0628 - accuracy: 0.3873 - val_loss: 1.0254 - val_accuracy: 0.4444
# Epoch 2/50
# 5/5 [==============================] - 0s 13ms/step - loss: 1.0291 - accuracy: 0.3873 - val_loss: 0.9881 - val_accuracy: 0.6111
# Epoch 3/50
# 5/5 [==============================] - 0s 18ms/step - loss: 1.0002 - accuracy: 0.5141 - val_loss: 0.9532 - val_accuracy: 0.7500
# Epoch 4/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.9655 - accuracy: 0.6549 - val_loss: 0.9236 - val_accuracy: 0.7778
# Epoch 5/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.9316 - accuracy: 0.7746 - val_loss: 0.8928 - val_accuracy: 0.8333
# Epoch 6/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.8960 - accuracy: 0.8803 - val_loss: 0.8563 - val_accuracy: 0.8333
# Epoch 7/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.8560 - accuracy: 0.8873 - val_loss: 0.8165 - val_accuracy: 0.8611
# Epoch 8/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.8139 - accuracy: 0.9014 - val_loss: 0.7711 - val_accuracy: 0.8889
# Epoch 9/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.7672 - accuracy: 0.9014 - val_loss: 0.7213 - val_accuracy: 0.8611
# Epoch 10/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7176 - accuracy: 0.9014 - val_loss: 0.6704 - val_accuracy: 0.8333
# Epoch 11/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6707 - accuracy: 0.9085 - val_loss: 0.6266 - val_accuracy: 0.8333
# Epoch 12/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.6219 - accuracy: 0.9225 - val_loss: 0.5872 - val_accuracy: 0.9167
# Epoch 13/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.5737 - accuracy: 0.9437 - val_loss: 0.5448 - val_accuracy: 0.9167
# Epoch 14/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.5257 - accuracy: 0.9507 - val_loss: 0.4982 - val_accuracy: 0.9167
# Epoch 15/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.4789 - accuracy: 0.9577 - val_loss: 0.4539 - val_accuracy: 0.9167
# Epoch 16/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.4337 - accuracy: 0.9648 - val_loss: 0.4208 - val_accuracy: 0.9167
# Epoch 17/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3938 - accuracy: 0.9507 - val_loss: 0.3939 - val_accuracy: 0.9167
# Epoch 18/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.3542 - accuracy: 0.9507 - val_loss: 0.3578 - val_accuracy: 0.9167
# Epoch 19/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.3207 - accuracy: 0.9648 - val_loss: 0.3232 - val_accuracy: 0.9167
# Epoch 20/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.2891 - accuracy: 0.9718 - val_loss: 0.2980 - val_accuracy: 0.9167
# Epoch 21/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.2691 - accuracy: 0.9718 - val_loss: 0.2904 - val_accuracy: 0.9167
# Epoch 22/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2400 - accuracy: 0.9648 - val_loss: 0.2611 - val_accuracy: 0.9167
# Epoch 23/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.2211 - accuracy: 0.9648 - val_loss: 0.2479 - val_accuracy: 0.9444
# Epoch 24/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2094 - accuracy: 0.9648 - val_loss: 0.2233 - val_accuracy: 0.9167
# Epoch 25/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1868 - accuracy: 0.9718 - val_loss: 0.2083 - val_accuracy: 0.9167
# Epoch 26/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1738 - accuracy: 0.9718 - val_loss: 0.1971 - val_accuracy: 0.9167
# Epoch 27/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1608 - accuracy: 0.9718 - val_loss: 0.1877 - val_accuracy: 0.9167
# Epoch 28/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1519 - accuracy: 0.9718 - val_loss: 0.1757 - val_accuracy: 0.9167
# Epoch 29/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1410 - accuracy: 0.9789 - val_loss: 0.1689 - val_accuracy: 0.9167
# Epoch 30/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1340 - accuracy: 0.9718 - val_loss: 0.1720 - val_accuracy: 0.9167
# Epoch 31/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1287 - accuracy: 0.9789 - val_loss: 0.1512 - val_accuracy: 0.9167
# Epoch 32/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1260 - accuracy: 0.9859 - val_loss: 0.1403 - val_accuracy: 0.9722
# Epoch 33/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1173 - accuracy: 0.9859 - val_loss: 0.1367 - val_accuracy: 0.9167
# Epoch 34/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1065 - accuracy: 0.9859 - val_loss: 0.1365 - val_accuracy: 0.9167
# Epoch 35/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1071 - accuracy: 0.9789 - val_loss: 0.1333 - val_accuracy: 0.9444
# Epoch 36/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0983 - accuracy: 0.9859 - val_loss: 0.1157 - val_accuracy: 0.9722
# Epoch 37/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0969 - accuracy: 0.9930 - val_loss: 0.1095 - val_accuracy: 0.9722
# Epoch 38/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0910 - accuracy: 0.9930 - val_loss: 0.1108 - val_accuracy: 0.9444
# Epoch 39/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0875 - accuracy: 0.9930 - val_loss: 0.1102 - val_accuracy: 0.9722
# Epoch 40/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0829 - accuracy: 0.9859 - val_loss: 0.0994 - val_accuracy: 0.9722
# Epoch 41/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0808 - accuracy: 0.9930 - val_loss: 0.0939 - val_accuracy: 0.9722
# Epoch 42/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0781 - accuracy: 0.9930 - val_loss: 0.0920 - val_accuracy: 0.9722
# Epoch 43/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0750 - accuracy: 0.9859 - val_loss: 0.0900 - val_accuracy: 1.0000
# Epoch 44/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0709 - accuracy: 0.9930 - val_loss: 0.0815 - val_accuracy: 0.9722
# Epoch 45/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0700 - accuracy: 0.9930 - val_loss: 0.0773 - val_accuracy: 0.9722
# Epoch 46/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0683 - accuracy: 0.9930 - val_loss: 0.0747 - val_accuracy: 0.9722
# Epoch 47/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0686 - accuracy: 0.9930 - val_loss: 0.0808 - val_accuracy: 1.0000
# Epoch 48/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0621 - accuracy: 0.9930 - val_loss: 0.0725 - val_accuracy: 1.0000
# Epoch 49/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0612 - accuracy: 0.9930 - val_loss: 0.0686 - val_accuracy: 1.0000
# Epoch 50/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0580 - accuracy: 0.9930 - val_loss: 0.0780 - val_accuracy: 1.0000

# %%
test_loss, test_acc = model_wine.evaluate(X_test, y_test)
print('Точность на тестовом наборе:', test_acc)
# Out:
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0780 - accuracy: 1.0000
# Точность на тестовом наборе: 1.0

# %%
predictions = model_wine.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 13ms/step

# %%
model_wine.save('wine_classification_model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
model_load=keras.models.load_model('wine_classification_model.h5')

# %% [markdown]
# # Задание 5

# %%
df = pd.read_csv('apple_quality.csv')
df.head()
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good

# %%
df.iloc[-1]
# Out:
# A_id                                         NaN
# Size                                         NaN
# Weight                                       NaN
# Sweetness                                    NaN
# Crunchiness                                  NaN
# Juiciness                                    NaN
# Ripeness                                     NaN
# Acidity        Created_by_Nidula_Elgiriyewithana
# Quality                                      NaN
# Name: 4000, dtype: object

# %%
df = df[:-1]

# %%
df = df.drop('A_id', axis=1)
labels = df['Quality']
labels = labels.map({'bad': 0, 'good': 1})
df = df.drop('Quality', axis=1)

# %%
null_count = df.isnull().sum().sum()
print('Number of null values:', null_count)
# Out:
# Number of null values: 0

# %%
X_train, X_test, y_train, y_test = train_test_split(df, labels, test_size=0.2, shuffle=True, random_state = 0)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
print(X_train.shape[1], len(np.unique(y_train)))
# Out:
# 7 2

# %%
num_features = X_train.shape[1]
num_classes = len(np.unique(y_train))
model_apple = keras.Sequential([
    keras.layers.Dense(64, activation='relu', input_shape=(num_features,)),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(num_classes, activation='softmax')
])

# %%
model_apple.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model_apple.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 2s 4ms/step - loss: 0.6400 - accuracy: 0.6744 - val_loss: 0.5979 - val_accuracy: 0.6888
# Epoch 2/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.5501 - accuracy: 0.7212 - val_loss: 0.5271 - val_accuracy: 0.7237
# Epoch 3/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.4979 - accuracy: 0.7469 - val_loss: 0.4646 - val_accuracy: 0.7775
# Epoch 4/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.4525 - accuracy: 0.7834 - val_loss: 0.4251 - val_accuracy: 0.7950
# Epoch 5/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.4135 - accuracy: 0.8091 - val_loss: 0.3884 - val_accuracy: 0.8175
# Epoch 6/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3834 - accuracy: 0.8259 - val_loss: 0.3744 - val_accuracy: 0.8238
# Epoch 7/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3590 - accuracy: 0.8378 - val_loss: 0.3578 - val_accuracy: 0.8213
# Epoch 8/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3488 - accuracy: 0.8397 - val_loss: 0.3917 - val_accuracy: 0.8087
# Epoch 9/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3354 - accuracy: 0.8459 - val_loss: 0.3331 - val_accuracy: 0.8425
# Epoch 10/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3286 - accuracy: 0.8547 - val_loss: 0.3264 - val_accuracy: 0.8575
# Epoch 11/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3306 - accuracy: 0.8444 - val_loss: 0.3291 - val_accuracy: 0.8600
# Epoch 12/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3173 - accuracy: 0.8594 - val_loss: 0.3113 - val_accuracy: 0.8675
# Epoch 13/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3142 - accuracy: 0.8572 - val_loss: 0.3233 - val_accuracy: 0.8525
# Epoch 14/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3057 - accuracy: 0.8603 - val_loss: 0.3104 - val_accuracy: 0.8700
# Epoch 15/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3120 - accuracy: 0.8647 - val_loss: 0.3161 - val_accuracy: 0.8600
# Epoch 16/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3042 - accuracy: 0.8656 - val_loss: 0.3362 - val_accuracy: 0.8500
# Epoch 17/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3159 - accuracy: 0.8562 - val_loss: 0.3133 - val_accuracy: 0.8712
# Epoch 18/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3047 - accuracy: 0.8606 - val_loss: 0.3154 - val_accuracy: 0.8662
# Epoch 19/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3029 - accuracy: 0.8612 - val_loss: 0.2986 - val_accuracy: 0.8712
# Epoch 20/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2989 - accuracy: 0.8659 - val_loss: 0.3002 - val_accuracy: 0.8763
# Epoch 21/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2944 - accuracy: 0.8644 - val_loss: 0.3446 - val_accuracy: 0.8512
# Epoch 22/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2953 - accuracy: 0.8719 - val_loss: 0.3134 - val_accuracy: 0.8700
# Epoch 23/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2992 - accuracy: 0.8566 - val_loss: 0.3238 - val_accuracy: 0.8512
# Epoch 24/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2917 - accuracy: 0.8712 - val_loss: 0.3055 - val_accuracy: 0.8687
# Epoch 25/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2924 - accuracy: 0.8712 - val_loss: 0.3233 - val_accuracy: 0.8475
# Epoch 26/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2872 - accuracy: 0.8728 - val_loss: 0.2979 - val_accuracy: 0.8650
# Epoch 27/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2886 - accuracy: 0.8722 - val_loss: 0.3090 - val_accuracy: 0.8662
# Epoch 28/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2839 - accuracy: 0.8756 - val_loss: 0.3225 - val_accuracy: 0.8600
# Epoch 29/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2862 - accuracy: 0.8725 - val_loss: 0.2940 - val_accuracy: 0.8725
# Epoch 30/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2793 - accuracy: 0.8734 - val_loss: 0.3009 - val_accuracy: 0.8637
# Epoch 31/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2868 - accuracy: 0.8706 - val_loss: 0.2946 - val_accuracy: 0.8775
# Epoch 32/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2903 - accuracy: 0.8684 - val_loss: 0.3142 - val_accuracy: 0.8675
# Epoch 33/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2790 - accuracy: 0.8731 - val_loss: 0.2907 - val_accuracy: 0.8737
# Epoch 34/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2764 - accuracy: 0.8794 - val_loss: 0.3839 - val_accuracy: 0.8250
# Epoch 35/50
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2876 - accuracy: 0.8731 - val_loss: 0.2985 - val_accuracy: 0.8625
# Epoch 36/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2786 - accuracy: 0.8816 - val_loss: 0.2933 - val_accuracy: 0.8687
# Epoch 37/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2802 - accuracy: 0.8734 - val_loss: 0.3254 - val_accuracy: 0.8600
# Epoch 38/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2762 - accuracy: 0.8763 - val_loss: 0.2987 - val_accuracy: 0.8687
# Epoch 39/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2744 - accuracy: 0.8759 - val_loss: 0.2976 - val_accuracy: 0.8675
# Epoch 40/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2712 - accuracy: 0.8794 - val_loss: 0.2956 - val_accuracy: 0.8700
# Epoch 41/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2744 - accuracy: 0.8778 - val_loss: 0.2901 - val_accuracy: 0.8700
# Epoch 42/50
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2680 - accuracy: 0.8744 - val_loss: 0.2858 - val_accuracy: 0.8800
# Epoch 43/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2743 - accuracy: 0.8797 - val_loss: 0.3032 - val_accuracy: 0.8700
# Epoch 44/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2853 - accuracy: 0.8700 - val_loss: 0.3462 - val_accuracy: 0.8300
# Epoch 45/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2682 - accuracy: 0.8788 - val_loss: 0.3006 - val_accuracy: 0.8625
# Epoch 46/50
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2672 - accuracy: 0.8772 - val_loss: 0.3385 - val_accuracy: 0.8500
# Epoch 47/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2706 - accuracy: 0.8794 - val_loss: 0.2955 - val_accuracy: 0.8763
# Epoch 48/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2642 - accuracy: 0.8800 - val_loss: 0.2951 - val_accuracy: 0.8737
# Epoch 49/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2650 - accuracy: 0.8816 - val_loss: 0.2905 - val_accuracy: 0.8775
# Epoch 50/50
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2566 - accuracy: 0.8897 - val_loss: 0.2976 - val_accuracy: 0.8750

# %%
test_loss, test_acc = model_apple.evaluate(X_test, y_test)
print('Точность на тестовом наборе:', round(test_acc, 3))
# Out:
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2976 - accuracy: 0.8750
# Точность на тестовом наборе: 0.875
